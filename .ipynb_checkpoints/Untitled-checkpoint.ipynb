# %%
import pandas as pd
from datetime import datetime

# %%
custom_date_parser = lambda x: datetime.strptime(x, "%YM%m")

data = pd.read_excel('CMO-Historical-Data-Monthly.xlsx', sheet_name='Monthly Prices', header=6, index_col=0, na_values="…", date_parser=custom_date_parser, parse_dates=[0])
# Out:
# Description
# Index Weights
# Monthly Indices
# Monthly Prices

# %%
data.head()
# Out:
#             CRUDE_PETRO  CRUDE_BRENT  CRUDE_DUBAI  CRUDE_WTI  COAL_AUS  \
# 1960-01-01         1.63         1.63         1.63        NaN       NaN
# 1960-02-01         1.63         1.63         1.63        NaN       NaN
# 1960-03-01         1.63         1.63         1.63        NaN       NaN
# 1960-04-01         1.63         1.63         1.63        NaN       NaN
# 1960-05-01         1.63         1.63         1.63        NaN       NaN
#
#            COAL_SAFRICA  NGAS_US  NGAS_EUR  NGAS_JP  iNATGAS  ...    ALUMINUM  \
# 1960-01-01          NaN     0.14  0.404774      NaN      NaN  ...  511.471832
# 1960-02-01          NaN     0.14  0.404774      NaN      NaN  ...  511.471832
# 1960-03-01          NaN     0.14  0.404774      NaN      NaN  ...  511.471832
# 1960-04-01          NaN     0.14  0.404774      NaN      NaN  ...  511.471832
# 1960-05-01          NaN     0.14  0.404774      NaN      NaN  ...  511.471832
#
# ...
