# %%
import pandas as pd

# %%
df = pd.read_csv('transactions-2023-01-11.csv')

# %%
df["Transaction Date"] = pd.to_datetime(df["Transaction Date"])
df
# Out:
#        Transaction Number    Transaction Date  Property ID Transaction Type  \
# 0              101-1-2021 2021-03-02 13:53:10     53982879         Mortgage
# 1              101-1-2021 2021-03-02 13:53:10     53982162         Mortgage
# 2              101-1-2021 2021-03-02 13:53:10    736630818         Mortgage
# 3              101-1-2021 2021-03-02 13:53:10    736630536         Mortgage
# 4              101-1-2021 2021-03-02 13:53:10    736630254         Mortgage
# ...                   ...                 ...          ...              ...
# 225365          95-8-2022 2022-02-03 08:26:40     83442054            Sales
# 225366         95-80-2021 2021-12-14 12:03:45     83441934            Sales
# 225367         95-83-2021 2021-12-16 12:39:22     83434266            Sales
# 225368          95-9-2021 2021-02-22 14:31:10     83442729            Sales
# 225369          95-9-2022 2022-02-03 08:27:50     83432211            Sales
#
#                                     Transaction sub type Registration type  \
# 0       Portfolio Mortgage Registration Pre-Registration          Off-Plan
# 1       Portfolio Mortgage Registration Pre-Registration          Off-Plan
# 2       Portfolio Mortgage Registration Pre-Registration          Off-Plan
# 3       Portfolio Mortgage Registration Pre-Registration          Off-Plan
# 4       Portfolio Mortgage Registration Pre-Registration          Off-Plan
# ...                                                  ...               ...
# 225365                               Delayed Development             Ready
# 225366                               Delayed Development             Ready
# 225367                               Delayed Development             Ready
# 225368                               Delayed Development             Ready
# 225369                               Delayed Development             Ready
#
#         Is Free Hold?        Usage           Area Property Type  ...  \
# 0           Free Hold  Residential      AL BARARI          Unit  ...
# 1           Free Hold  Residential      AL BARARI          Unit  ...
# 2           Free Hold  Residential      AL BARARI          Unit  ...
# 3           Free Hold  Residential      AL BARARI          Unit  ...
# 4           Free Hold  Residential      AL BARARI          Unit  ...
# ...               ...          ...            ...           ...  ...
# 225365  Non Free Hold  Residential  SILICON OASIS          Unit  ...
# 225366  Non Free Hold  Residential  SILICON OASIS          Unit  ...
# 225367  Non Free Hold  Residential  SILICON OASIS          Unit  ...
# 225368  Non Free Hold  Residential  SILICON OASIS          Unit  ...
# 225369  Non Free Hold  Residential  SILICON OASIS          Unit  ...
#
#        Property Size (sq.m)  Room(s)        Parking  Nearest Metro  \
# 0                    138.93    2 B/R              1            NaN
# 1                     87.26    1 B/R           B-38            NaN
# 2                     76.13    1 B/R           B-60            NaN
# 3                    130.05    2 B/R           B-29            NaN
# 4                     52.15   Studio           G-17            NaN
# ...                     ...      ...            ...            ...
# 225365               108.87    2 B/R  B1-106 , G-09            NaN
# 225366                49.18   Studio         B2-233            NaN
# 225367               143.91    2 B/R         B2-157            NaN
# 225368                76.37    1 B/R         B1-160            NaN
# 225369               121.89    2 B/R          B1-93            NaN
#
#        Nearest Mall      Nearest Landmark No. of Buyer No. of Seller  \
# 0               NaN  IMG World Adventures            0             0
# 1               NaN  IMG World Adventures            0             0
# 2               NaN  IMG World Adventures            0             0
# 3               NaN  IMG World Adventures            0             0
# 4               NaN  IMG World Adventures            0             0
# ...             ...                   ...          ...           ...
# 225365          NaN  IMG World Adventures            0             0
# 225366          NaN  IMG World Adventures            0             0
# 225367          NaN  IMG World Adventures            0             0
# 225368          NaN  IMG World Adventures            0             0
# 225369          NaN  IMG World Adventures            0             0
#
#        Master Project                  Project
# 0                 NaN  Seventh Heaven - Ashjar
# 1                 NaN  Seventh Heaven - Ashjar
# 2                 NaN  Seventh Heaven - Ashjar
# 3                 NaN  Seventh Heaven - Ashjar
# 4                 NaN  Seventh Heaven - Ashjar
# ...               ...                      ...
# 225365            NaN             ARABIAN GATE
# 225366            NaN             ARABIAN GATE
# 225367            NaN             ARABIAN GATE
# 225368            NaN             ARABIAN GATE
# 225369            NaN             ARABIAN GATE
#
# [225370 rows x 23 columns]

# %%
df[['Transaction Date'] < '2022-']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225370 entries, 0 to 225369
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Transaction Number       225370 non-null  object
#  1   Transaction Date         225370 non-null  object
#  2   Property ID              225370 non-null  int64
#  3   Transaction Type         225370 non-null  object
#  4   Transaction sub type     225370 non-null  object
#  5   Registration type        225370 non-null  object
#  6   Is Free Hold?            225370 non-null  object
#  7   Usage                    225370 non-null  object
#  8   Area                     225370 non-null  object
#  9   Property Type            225370 non-null  object
#  10  Property Sub Type        218331 non-null  object
#  11  Amount                   225370 non-null  float64
#  12  Transaction Size (sq.m)  223144 non-null  float64
#  13  Property Size (sq.m)     225370 non-null  float64
#  14  Room(s)                  177421 non-null  object
#  15  Parking                  147114 non-null  object
#  16  Nearest Metro            156924 non-null  object
#  17  Nearest Mall             156467 non-null  object
#  18  Nearest Landmark         182069 non-null  object
#  19  No. of Buyer             225370 non-null  int64
#  20  No. of Seller            225370 non-null  int64
#  21  Master Project           190 non-null     object
#  22  Project                  173323 non-null  object
# dtypes: float64(3), int64(3), object(17)
# memory usage: 39.5+ MB

# %%
df['Usage'].hist()

# %%
df['Transaction Type'].hist()

# %%
df['Amount'].hist()

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(df[['Amount', 'Property Size (sq.m)']], figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd05178cbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd051b81550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd051c54970>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fd051be9df0>]],
#       dtype=object)

# %%
df[['Amount', 'Property Size (sq.m)']]
# Out:
#             Amount  Property Size (sq.m)
# 0       1435909.09                138.93
# 1       1435909.09                 87.26
# 2       1435909.09                 76.13
# 3       1435909.09                130.05
# 4       1435909.09                 52.15
# ...            ...                   ...
# 225365   814923.00                108.87
# 225366   419796.00                 49.18
# 225367  1039412.00                143.91
# 225368   548125.00                 76.37
# 225369   840352.00                121.89
#
# [225370 rows x 2 columns]
