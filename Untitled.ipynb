# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv('transactions-2023-01-11.csv')

# %%
def drop_excess_columns(data):
    # Drop high cardinality columns
    data = data.drop(columns=["Transaction Number", "Property ID", "Transaction Size (sq.m)", "Parking", "Project"])
    # Drop low-cardinality columns
    data = data.drop(columns=["Registration type", "Is Free Hold?", "Master Project"])
    # Drop leaky columns
    data = data.drop(columns=["Transaction sub type", "Property Type", "Room(s)", "No. of Buyer", "No. of Seller"])
    return data

# %%
df = drop_excess_columns(df)

# %%
def get_oil_price():
    # data from https://tradingeconomics.com/commodity/crude-oil
    r = requests.get('https://markets.tradingeconomics.com/chart?s=cl1:com&interval=1d&span=5y&securify=new&url=/commodity/crude-oil&AUTH=Iyl9RVWfzjLi7c1HYd9NvPSbYw4QDhtHNC8UlBnpCaBG6anMsTTRMHyqxcJokUmS&ohlc=0')
    
    oil_data = pd.DataFrame(r.json()['series'][0]['data']).rename(columns={"y": "price"})
    oil_data = oil_data[(oil_data['date'] > '2021-03-01') & (oil_data['date'] < '2022-02-04')]

    return oil_data

# %%
oil_data = get_oil_price()
oil_data
# Out:
#                      date              x  price  percentChange  change
# 880   2021-03-01T00:00:00  1614556800000  60.64      -1.398374   -0.86
# 881   2021-03-02T00:00:00  1614643200000  59.75      -1.467678   -0.89
# 882   2021-03-03T00:00:00  1614729600000  61.28       2.560669    1.53
# 883   2021-03-04T00:00:00  1614816000000  63.83       4.161227    2.55
# 884   2021-03-05T00:00:00  1614902400000  66.09       3.540655    2.26
# ...                   ...            ...    ...            ...     ...
# 1116  2022-01-28T00:00:00  1643328000000  85.43       0.164146    0.14
# 1117  2022-01-31T00:00:00  1643587200000  86.49       1.240782    1.06
# 1118  2022-02-01T00:00:00  1643673600000  86.46      -0.034686   -0.03
# 1119  2022-02-02T00:00:00  1643760000000  86.69       0.266019    0.23
# 1120  2022-02-03T00:00:00  1643846400000  88.45       2.030223    1.76
#
# [241 rows x 5 columns]

# %%
def drop_period_after_war(data):
    war_date = '2022-02-24'
    return data[data['Transaction Date'] < war_date]

# %%
df = drop_period_after_war(df)

# %%
def merge_oil_to_data(data, oil):
    data['date_without_time'] = pd.to_datetime(data['Transaction Date']).dt.strftime('%Y-%m-%d')
    oil['date_without_time'] = pd.to_datetime(oil['date']).dt.strftime('%Y-%m-%d')
    data = data.merge(oil, left_on='date_without_time', right_on='date_without_time')
    return data

# %%
df = merge_oil_to_data(df, oil_data)

# %%
def add_norm_amount(data):
    data['norm_amount']  = (data['Amount'] - data['Amount'].min()) / (data['Amount'].max() - data['Amount'].min()) 
    return data

# %%
df = add_norm_amount(df)

# %%
df
# Out:
#           Transaction Date Transaction Type        Usage  \
# 0      2021-03-02 13:53:10         Mortgage  Residential
# 1      2021-03-02 13:53:10         Mortgage  Residential
# 2      2021-03-02 13:53:10         Mortgage  Residential
# 3      2021-03-02 13:53:10         Mortgage  Residential
# 4      2021-03-02 13:53:10         Mortgage  Residential
# ...                    ...              ...          ...
# 69700  2021-07-23 03:41:08         Mortgage  Residential
# 69701  2021-07-30 01:08:56         Mortgage  Residential
# 69702  2021-07-30 01:42:39         Mortgage  Residential
# 69703  2021-07-30 01:44:58         Mortgage  Residential
# 69704  2021-08-12 13:59:36            Sales  Residential
#
#                           Area Property Sub Type      Amount  \
# 0                    AL BARARI              Flat  1435909.09
# 1                    AL BARARI              Flat  1435909.09
# 2                    AL BARARI              Flat  1435909.09
# 3                    AL BARARI              Flat  1435909.09
# 4                    AL BARARI              Flat  1435909.09
# ...                        ...               ...         ...
# 69700  JUMEIRAH VILLAGE CIRCLE              Flat   888655.00
# 69701       ARABIAN RANCHES II       Residential  3283133.00
# 69702       Nad Al Shiba Third               NaN  2270000.00
# 69703       Nad Al Shiba Third               NaN  2155300.00
# 69704             BUSINESS BAY              Flat  2872276.00
#
#        Property Size (sq.m)               Nearest Metro          Nearest Mall  \
# 0                    138.93                         NaN                   NaN
# 1                     87.26                         NaN                   NaN
# 2                     76.13                         NaN                   NaN
# 3                    130.05                         NaN                   NaN
# 4                     52.15                         NaN                   NaN
# ...                     ...                         ...                   ...
# 69700                106.55         Dubai Internet City  Mall of the Emirates
# 69701                836.75                         NaN                   NaN
# 69702                468.74         Creek Metro Station    City Centre Mirdif
# 69703                469.30         Creek Metro Station    City Centre Mirdif
# 69704                184.03  Business Bay Metro Station            Dubai Mall
#
#                    Nearest Landmark date_without_time                 date  \
# 0              IMG World Adventures        2021-03-02  2021-03-02T00:00:00
# 1              IMG World Adventures        2021-03-02  2021-03-02T00:00:00
# 2              IMG World Adventures        2021-03-02  2021-03-02T00:00:00
# 3              IMG World Adventures        2021-03-02  2021-03-02T00:00:00
# 4              IMG World Adventures        2021-03-02  2021-03-02T00:00:00
# ...                             ...               ...                  ...
# 69700  Sports City Swimming Academy        2021-07-23  2021-07-23T00:00:00
# 69701                    Motor City        2021-07-30  2021-07-30T00:00:00
# 69702                           NaN        2021-07-30  2021-07-30T00:00:00
# 69703                           NaN        2021-07-30  2021-07-30T00:00:00
# 69704                Downtown Dubai        2021-08-12  2021-08-12T00:00:00
#
#                    x  price  percentChange  change  norm_amount
# 0      1614643200000  59.75      -1.467678   -0.89     0.000305
# 1      1614643200000  59.75      -1.467678   -0.89     0.000305
# 2      1614643200000  59.75      -1.467678   -0.89     0.000305
# 3      1614643200000  59.75      -1.467678   -0.89     0.000305
# 4      1614643200000  59.75      -1.467678   -0.89     0.000305
# ...              ...    ...            ...     ...          ...
# 69700  1626998400000  72.07       0.222500    0.16     0.000189
# 69701  1627603200000  73.95       0.448248    0.33     0.000698
# 69702  1627603200000  73.95       0.448248    0.33     0.000483
# 69703  1627603200000  73.95       0.448248    0.33     0.000458
# 69704  1628726400000  69.09      -0.231047   -0.16     0.000611
#
# [69705 rows x 17 columns]

# %%
from pandas.plotting import scatter_matrix

def plot_matrix(data):
    scatter_matrix(df[['norm_amount', 'Property Size (sq.m)']], figsize=(12, 8))
    scatter_matrix(df[['norm_amount', 'price']], figsize=(12, 8))
    return df['Amount'].describe()

# %%
plot_matrix(df)
# Out:
# count    6.970500e+04
# mean     3.232904e+06
# std      3.131844e+07
# min      1.000000e+03
# 25%      7.379440e+05
# 50%      1.360000e+06
# 75%      2.437594e+06
# max      4.701320e+09
# Name: Amount, dtype: float64
